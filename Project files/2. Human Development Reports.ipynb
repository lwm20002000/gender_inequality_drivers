# %%
import pandas as pd
from functools import reduce
import re
import numpy as np

# %%
country_ids = pd.read_csv('country_ids.csv')

# %%
def read_human_dev_report(file, sheet, skiprows, skipfooter):
    xls = pd.ExcelFile(file)
    df = pd.read_excel(xls, sheet, 
                       header = 0,
                       skiprows = skiprows,
                       skipfooter = skipfooter)
    
    return df

# %%
def fix_df(df, col_names):
    df.columns = df.columns.str.strip()
    df = df[col_names]
    
    return df

# %%
# clean up country names to match Read Country Code file
to_replace_ = ['Palestine, State of', 'Hong Kong, China (SAR)', 'Russian Federation', 
               'Korea (Republic of)', 'Iran (Islamic Republic of)']
replace_with_ = ['Palestine', 'Hong Kong', 'Russia', 
                 'South Korea', 'Iran']

def fix_country_names(df, col_name):
    df[col_name] = df[col_name].replace(to_replace_, replace_with_)
    df[col_name] = df[col_name].replace('[\(].*[\)]', '', regex=True)
    
    return df

# %%
# copy human development report from countries to countries with cities and the UK
def update_country_cities(df, df_new_col, df_UK_col):
    df.loc['Canada, Ontario', df_new_col] = df.loc['Canada', df_new_col]
    df.loc['Canada, Quebec', df_new_col] = df.loc['Canada', df_new_col]
    df.loc['Russia, Moscow', df_new_col] = df.loc['Russia', df_new_col]
    df.loc['United Arab Emirates, Abu Dhabi', df_new_col] = df.loc['United Arab Emirates', df_new_col]
    df.loc['United Arab Emirates, Dubai', df_new_col] = df.loc['United Arab Emirates', df_new_col]
    df.loc['England', df_new_col] = df_UK_col
    df.loc['Northern Ireland', df_new_col] = df_UK_col

    return df

# %%
# Table 1. Human Development Index and its components 
hdi = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Table 1', 4, 41)

hdi_col_names = ['Unnamed: 1', 'Human Development Index (HDI)', 'Life expectancy at birth',
             'Expected years of schooling', 'Mean years of schooling', 'Gross national income (GNI) per capita',
             'HDI rank']

hdi = fix_df(hdi, hdi_col_names)

hdi = hdi.rename(columns={'Unnamed: 1': 'Country'})

# %%
hdi
# Out:
#                                                Country  \
# 0                                              Country
# 1                                                  NaN
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                               Norway
# 4                                              Ireland
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# 224                                              World
#
#     Human Development Index (HDI) Life expectancy at birth  \
# 0                           Value                  (years)
# 1                            2019                     2019
# 2                             NaN                      NaN
# 3                           0.957                     82.4
# 4                           0.955                    82.31
# ..                            ...                      ...
# 220                         0.728                  72.0046
# 221                           NaN                      NaN
# 222                           0.9                  80.3522
# 223                           NaN                      NaN
# 224                         0.737                  72.7525
#
#     Expected years of schooling Mean years of schooling  \
# 0                       (years)                 (years)
# 1                          2019                    2019
# 2                           NaN                     NaN
# 3                       18.0662                 12.8978
# 4                       18.7053                 12.6663
# ..                          ...                     ...
# 220                     12.3092                 8.72368
# 221                         NaN                     NaN
# 222                      16.286                 11.9761
# 223                         NaN                     NaN
# 224                     12.7064                 8.53274
#
#     Gross national income (GNI) per capita HDI rank
# 0                             (2017 PPP $)      NaN
# 1                                     2019     2018
# 2                                      NaN      NaN
# 3                                  66494.3        1
# 4                                  68370.6        3
# ..                                     ...      ...
# 220                                16824.8        —
# 221                                    NaN      NaN
# 222                                  44967        —
# 223                                    NaN      NaN
# 224                                16733.8        —
#
# [225 rows x 7 columns]

# %%
# Table 4. Gender Development Index
gdi = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Table 4', 3, 35)

gdi_col_names = ['Unnamed: 1', 'Gender Development Index', 'Unnamed: 4', 'Human Development Index',
                 'Unnamed: 8', 'Life expectancy at birth', 'Unnamed: 12', 'Expected years of schooling',
                 'Unnamed: 16', 'Mean years of schooling', 'Unnamed: 20', 'Estimated  gross national income per capita',
                 'Unnamed: 24']

gdi = fix_df(gdi, gdi_col_names)

gdi_rename_dict = {'Unnamed: 1': 'Country',
                   'Unnamed: 4': 'GDI Group',
                   'Human Development Index': 'HDI Female',
                   'Unnamed: 8': 'HDI Male',
                   'Life expectancy at birth': 'Life expectancy at birth Female',
                   'Unnamed: 12': 'Life expectancy at birth Male',
                   'Expected years of schooling': 'Expected years of schooling Female',
                   'Unnamed: 16': 'Expected years of schooling Male',
                   'Mean years of schooling': 'Mean years of schooling Female',
                   'Unnamed: 20': 'Mean years of schooling Male',
                   'Estimated gross national income per capita': 'GNI Female',
                   'Unnamed: 24': 'GNI Male'}

gdi = gdi.rename(columns=gdi_rename_dict)

# %%
gdi
# Out:
#                                                Country  \
# 0                                                  NaN
# 1                                              Country
# 2                                                  NaN
# 3                          VERY HIGH HUMAN DEVELOPMENT
# 4                                               Norway
# ..                                                 ...
# 221                     Small island developing states
# 222                                                NaN
# 223  Organisation for Economic Co-operation and Dev...
# 224                                                NaN
# 225                                              World
#
#     Gender Development Index GDI Group HDI Female  HDI Male  \
# 0                        NaN       NaN      Value       NaN
# 1                      Value     Group     Female      Male
# 2                       2019      2019       2019      2019
# 3                        NaN       NaN        NaN       NaN
# 4                   0.989939         1   0.948956  0.958601
# ..                       ...       ...        ...       ...
# 221                 0.959154         —   0.718401  0.748994
# 222                      NaN       NaN        NaN       NaN
# 223                 0.978219         —   0.887348  0.907106
# 224                      NaN       NaN        NaN       NaN
# 225                 0.943092         —   0.714298    0.7574
#
#     Life expectancy at birth Female Life expectancy at birth Male  \
# 0                           (years)                           NaN
# 1                            Female                          Male
# 2                              2019                          2019
# 3                               NaN                           NaN
# 4                            84.377                        80.447
# ..                              ...                           ...
# 221                         74.1144                       69.9724
# 222                             NaN                           NaN
# 223                         82.9409                        77.724
# 224                             NaN                           NaN
# 225                         75.0358                        70.573
#
#     Expected years of schooling Female Expected years of schooling Male  \
# 0                              (years)                              NaN
# 1                               Female                             Male
# 2                                 2019                             2019
# 3                                  NaN                              NaN
# 4                              18.7595                          17.4136
# ..                                 ...                              ...
# 221                            12.9414                          12.6875
# 222                                NaN                              NaN
# 223                            16.5545                          16.0037
# 224                                NaN                              NaN
# 225                            12.7179                          12.7034
#
#     Mean years of schooling Female Mean years of schooling Male  \
# 0                          (years)                          NaN
# 1                           Female                         Male
# 2                             2019                         2019
# 3                              NaN                          NaN
# 4                           12.977                      12.8166
# ..                             ...                          ...
# 221                        8.49178                      9.18303
# 222                            NaN                          NaN
# 223                        11.8622                       12.087
# 224                            NaN                          NaN
# 225                         8.1093                       9.1617
#
#     Estimated  gross national income per capita GNI Male
# 0                                  (2017 PPP $)      NaN
# 1                                        Female     Male
# 2                                          2019     2019
# 3                                           NaN      NaN
# 4                                       58548.4  74279.9
# ..                                          ...      ...
# 221                                     12281.1  21333.8
# 222                                         NaN      NaN
# 223                                     34593.4  55679.2
# 224                                         NaN      NaN
# 225                                     12063.5  21323.4
#
# [226 rows x 13 columns]

# %%
# Table 5. Gender Inequality Index
gii = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Table 5', 3, 41)

gii_col_names = ['Unnamed: 1', 'Gender Inequality Index', 'Unnamed: 4', 'Maternal mortality ratio', 
                 'Adolescent birth rate', 'Share of seats in parliament', 'Population with at least some secondary education', 
                 'Unnamed: 14', 'Labour force participation rate', 'Unnamed: 18']

gii = fix_df(gii, gii_col_names)

gii_rename_dict = {'Unnamed: 4': 'GII Rank',
                   'Unnamed: 1': 'Country',
                   'Share of seats in parliament': 'Share of seats in parliament held by women',
                   'Population with at least some secondary education': 'Share at least some secondary education Female',
                   'Unnamed: 14': 'Share at least some secondary education Male',
                   'Labour force participation rate': 'Labour force participation rate Female',
                   'Unnamed: 18': 'Labour force participation rate Male'}

gii = gii.rename(columns=gii_rename_dict)

# %%
gii
# Out:
#                              Country Gender Inequality Index GII Rank  \
# 0                                NaN                   Value     Rank
# 1                            Country                     NaN      NaN
# 2                                NaN                    2019     2019
# 3        VERY HIGH HUMAN DEVELOPMENT                     NaN      NaN
# 4                             Norway                   0.045        6
# ..                               ...                     ...      ...
# 212                          Regions                     NaN      NaN
# 213                      Arab States                   0.518        —
# 214        East Asia and the Pacific                   0.324        —
# 215          Europe and Central Asia                   0.256        —
# 216  Latin America and the Caribbean                   0.389        —
#
#              Maternal mortality ratio                Adolescent birth rate  \
# 0    (deaths per 100,000 live births)  (births per 1,000 women ages 15–19)
# 1                                 NaN                                  NaN
# 2                                2017                            2015-2020
# 3                                 NaN                                  NaN
# 4                                   2                                5.141
# ..                                ...                                  ...
# 212                               NaN                                  NaN
# 213                            135.38                              46.7762
# 214                           73.0728                              22.1456
# 215                           19.8915                              27.7675
# 216                           72.7379                              63.2338
#
#     Share of seats in parliament held by women  \
# 0                            (% held by women)
# 1                                          NaN
# 2                                         2019
# 3                                          NaN
# 4                                      40.8284
# ..                                         ...
# 212                                        NaN
# 213                                    17.9915
# 214                                    20.1752
# 215                                    23.1272
# 216                                    31.4252
#
#     Share at least some secondary education Female  \
# 0                            (% ages 25 and older)
# 1                                           Female
# 2                                        2015–2019
# 3                                              NaN
# 4                                          95.3928
# ..                                             ...
# 212                                            NaN
# 213                                        49.3221
# 214                                        69.3692
# 215                                        79.8655
# 216                                        60.3717
#
#     Share at least some secondary education Male  \
# 0                                            NaN
# 1                                           Male
# 2                                      2015–2019
# 3                                            NaN
# 4                                          94.86
# ..                                           ...
# 212                                          NaN
# 213                                      55.7774
# 214                                      76.5283
# 215                                      88.0947
# 216                                      59.7422
#
#     Labour force participation rate Female  \
# 0                    (% ages 15 and older)
# 1                                   Female
# 2                                     2019
# 3                                      NaN
# 4                                    60.37
# ..                                     ...
# 212                                    NaN
# 213                                20.6571
# 214                                59.2462
# 215                                45.0142
# 216                                52.0836
#
#     Labour force participation rate Male
# 0                                    NaN
# 1                                   Male
# 2                                   2019
# 3                                    NaN
# 4                                 67.192
# ..                                   ...
# 212                                  NaN
# 213                              73.0391
# 214                              76.5069
# 215                              69.9611
# 216                              76.8556
#
# [217 rows x 10 columns]

# %%
# Table 9. Education achievements
ea = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Table 9', 4, 23)

ea_col_names = ['Unnamed: 1', 'Youth\n(% ages 15–24)', 'Unnamed: 6', 'Population with at least some secondary education',
                'Pre-primary', 'Primary', 'Secondary', 'Tertiary', 'Primary school dropout rate',
                'Survival rate to the last grade of lower secondary general education', 'Government expenditure on education']

ea = fix_df(ea, ea_col_names)

ea_rename_dict = {'Unnamed: 1': 'Country',
                  'Youth\n(% ages 15–24)': 'Youth literacy rate Female',
                  'Unnamed: 6': 'Youth literacy rate Male',
                  'Survival rate to the last grade of lower secondary general education': 'Lower secondary retention'}

ea = ea.rename(columns=ea_rename_dict)

# %%
ea
# Out:
#                                                Country  \
# 0                                              Country
# 1                                                  NaN
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                               Norway
# 4                                              Ireland
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# 224                                              World
#
#     Youth literacy rate Female Youth literacy rate Male  \
# 0                       Female                     Male
# 1                    2008-2018                2008-2018
# 2                          NaN                      NaN
# 3                           ..                       ..
# 4                           ..                       ..
# ..                         ...                      ...
# 220                    88.6202                   88.321
# 221                        NaN                      NaN
# 222                         ..                       ..
# 223                        NaN                      NaN
# 224                    89.6307                  92.3898
#
#     Population with at least some secondary education  \
# 0                               (% ages 25 and older)
# 1                                           2015-2019
# 2                                                 NaN
# 3                                             94.9208
# 4                                             81.1196
# ..                                                ...
# 220                                           59.5062
# 221                                               NaN
# 222                                           85.4057
# 223                                               NaN
# 224                                           64.5041
#
#                        Pre-primary                               Primary  \
# 0    (% of preschool-age children)  (% of primary school–age population)
# 1                        2014-2019                             2014-2019
# 2                              NaN                                   NaN
# 3                          95.3653                                100.26
# 4                           163.44                               100.853
# ..                             ...                                   ...
# 220                             ..                               104.749
# 221                            NaN                                   NaN
# 222                        80.6191                               102.569
# 223                            NaN                                   NaN
# 224                        51.5174                               104.078
#
#                                   Secondary  \
# 0    (% of secondary school–age population)
# 1                                 2014-2019
# 2                                       NaN
# 3                                   116.874
# 4                                   125.307
# ..                                      ...
# 220                                 77.3819
# 221                                     NaN
# 222                                  106.52
# 223                                     NaN
# 224                                 76.1623
#
#                                   Tertiary   Primary school dropout rate  \
# 0    (% of tertiary school–age population)  (% of primary school cohort)
# 1                                2014-2019                     2008-2018
# 2                                      NaN                           NaN
# 3                                  81.9924                        0.8978
# 4                                  77.7806                            ..
# ..                                     ...                           ...
# 220                                     ..                            ..
# 221                                    NaN                           NaN
# 222                                72.4034                            ..
# 223                                    NaN                           NaN
# 224                                38.6602                       19.8309
#
#     Lower secondary retention Government expenditure on education
# 0                         (%)                          (% of GDP)
# 1                   2008-2018                           2013-2018
# 2                         NaN                                 NaN
# 3                     98.7565                              7.9761
# 4                     99.4177                             3.71973
# ..                        ...                                 ...
# 220                        ..                                  ..
# 221                       NaN                                 NaN
# 222                        ..                             4.83567
# 223                       NaN                                 NaN
# 224                   90.8816                             4.68072
#
# [225 rows x 11 columns]

# %%
# Table 13. Human and capital mobility
hcm = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Table 13', 5, 47)

hcm_col_names = ['Unnamed: 1', 'Exports and imports', 'Stock of immigrants', 'International student mobility',
               'International inbound tourists', 'Total', 'Female']

hcm = fix_df(hcm, hcm_col_names)

hcm_rename_dict = {'Unnamed: 1': 'Country',
                   'Total': 'Share of internet users',
                   'Female': 'Share of female internet users'}               

hcm = hcm.rename(columns=hcm_rename_dict)

# %%
hcm
# Out:
#                                                Country Exports and imports  \
# 0                                              Country          (% of GDP)
# 1                                                  NaN                2019
# 2                          Very high human development                 NaN
# 3                                               Norway             72.1465
# 4                                              Ireland             239.215
# ..                                                 ...                 ...
# 220                     Small island developing states             203.132
# 221                                                NaN                 NaN
# 222  Organisation for Economic Co-operation and Dev...              55.825
# 223                                                NaN                 NaN
# 224                                              World              55.578
#
#     Stock of immigrants   International student mobility  \
# 0     (% of population)  (% of total tertiary enrolment)
# 1                  2019                        2010-2017
# 2                   NaN                              NaN
# 3               16.1329                         -3.07912
# 4               17.0725                          2.23969
# ..                  ...                              ...
# 220             6.20709                          2.56106
# 221                 NaN                              NaN
# 222             10.5898                          4.52689
# 223                 NaN                              NaN
# 224             3.51246                          0.41954
#
#     International inbound tourists Share of internet users  \
# 0                      (thousands)       (% of population)
# 1                             2018                    2018
# 2                              NaN                     NaN
# 3                             5688                 96.4917
# 4                            10926                 84.5223
# ..                             ...                     ...
# 220                        51408.2                 50.0993
# 221                            NaN                     NaN
# 222                         791285                 82.6607
# 223                            NaN                     NaN
# 224                    1.39333e+06                 50.4456
#
#     Share of female internet users
# 0         (% of female population)
# 1                             2018
# 2                              NaN
# 3                               97
# 4                             85.7
# ..                             ...
# 220                             ..
# 221                            NaN
# 222                        78.4586
# 223                            NaN
# 224                             ..
#
# [225 rows x 7 columns]

# %%
# Dashboard 1. Quality of human development
qhd = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Dashboard 1', 8, 35)

qhd_col_names = ['Unnamed: 1', 'Lost health expectancy', 'Physicians', 'Hospital beds', 'Pupil–teacher ratio, primary school',
                 'Schools with access to the Internet', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20', 
                 'Unnamed: 22', 'Unnamed: 24', 'Unnamed: 26', 'Unnamed: 28']

qhd = fix_df(qhd, qhd_col_names)

qhd_rename_dict = {'Unnamed: 1': 'Country',
                   'Physicians': 'Physicians per 10,000 people',
                   'Hospital beds': 'Hospital beds per 10,000 people',
                   'Schools with access to the Internet': 'Primary schools with access to the Internet',
                   'Unnamed: 14': 'Secondary schools with access to the Internet',
                   'Unnamed: 16': 'PISA Reading',
                   'Unnamed: 18': 'PISA Math',
                   'Unnamed: 20': 'PISA Science',
                   'Unnamed: 22': 'Share of vulnerable employment',
                   'Unnamed: 24': 'Share of rural population with access to electricity',
                   'Unnamed: 26': 'Share of population with safe drinking water',
                   'Unnamed: 28': 'Share of population with sanitation services'}

qhd = qhd.rename(columns=qhd_rename_dict)

# %%
qhd
# Out:
#                                                Country Lost health expectancy  \
# 0                                                  NaN                    NaN
# 1                                              Country                    (%)
# 2                                                  NaN                   2019
# 3                          Very high human development                    NaN
# 4                                               Norway                14.5554
# ..                                                 ...                    ...
# 221                     Small island developing states                12.7277
# 222                                                NaN                    NaN
# 223  Organisation for Economic Co-operation and Dev...                14.4986
# 224                                                NaN                    NaN
# 225                                              World                13.2162
#
#     Physicians per 10,000 people Hospital beds per 10,000 people  \
# 0                            NaN                             NaN
# 1            (per 10,000 people)                             NaN
# 2                      2010–2018                       2010–2019
# 3                            NaN                             NaN
# 4                         29.164                            35.3
# ..                           ...                             ...
# 221                      23.1128                         25.1943
# 222                          NaN                             NaN
# 223                      29.1675                         46.7569
# 224                          NaN                             NaN
# 225                      15.4696                         26.9017
#
#     Pupil–teacher ratio, primary school  \
# 0                                   NaN
# 1                  (pupils per teacher)
# 2                             2010–2019
# 3                                   NaN
# 4                               8.59418
# ..                                  ...
# 221                             18.9996
# 222                                 NaN
# 223                             15.4605
# 224                                 NaN
# 225                             23.5663
#
#     Primary schools with access to the Internet  \
# 0                               Primary schools
# 1                                           NaN
# 2                                     2010–2019
# 3                                           NaN
# 4                                           100
# ..                                          ...
# 221                                           —
# 222                                         NaN
# 223                                           —
# 224                                         NaN
# 225                                           —
#
#     Secondary schools with access to the Internet  \
# 0                              Secondary schools
# 1                                             NaN
# 2                                       2010–2019
# 3                                             NaN
# 4                                             100
# ..                                            ...
# 221                                             —
# 222                                           NaN
# 223                                             —
# 224                                           NaN
# 225                                             —
#
#                                           PISA Reading    PISA Math  \
# 0    Programme for International Student Assessment...          NaN
# 1                                              Reading  Mathematics
# 2                                                 2018         2018
# 3                                                  NaN          NaN
# 4                                              499.451      500.964
# ..                                                 ...          ...
# 221                                                  —            —
# 222                                                NaN          NaN
# 223                                                  —            —
# 224                                                NaN          NaN
# 225                                                  —            —
#
#     PISA Science Share of vulnerable employment  \
# 0            NaN          Vulnerable employment
# 1        Science        (% of total employment)
# 2           2018                           2019
# 3            NaN                            NaN
# 4        490.413                          4.906
# ..           ...                            ...
# 221            —                        40.5134
# 222          NaN                            NaN
# 223            —                        12.7567
# 224          NaN                            NaN
# 225            —                        44.7093
#
#     Share of rural population with access to electricity  \
# 0          Rural population with access to electricity
# 1                                                  (%)
# 2                                                 2018
# 3                                                  NaN
# 4                                                  100
# ..                                                 ...
# 221                                            62.5455
# 222                                                NaN
# 223                                             99.988
# 224                                                NaN
# 225                                            80.2874
#
#           Share of population with safe drinking water  \
# 0    Population using safely managed drinking-water...
# 1                                                  NaN
# 2                                                 2017
# 3                                                  NaN
# 4                                                   98
# ..                                                 ...
# 221                                                 ..
# 222                                                NaN
# 223                                            91.8787
# 224                                                NaN
# 225                                                 ..
#
#           Share of population with sanitation services
# 0    Population using safely managed sanitation ser...
# 1                                                  NaN
# 2                                                 2017
# 3                                                  NaN
# 4                                                   76
# ..                                                 ...
# 221                                                 ..
# 222                                                NaN
# 223                                            84.3057
# 224                                                NaN
# 225                                                 ..
#
# [226 rows x 14 columns]

# %%
# Dashboard 2. Life-course gender gap 
lgg = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Dashboard 2', 9, 36)

lgg_col_names = ['Unnamed: 1', 'Unnamed: 2', 'Gross enrolment ratio', 'Unnamed: 6', 'Unnamed: 8',
                 'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20',
                 'Unnamed: 22', 'Unnamed: 24', 'Unnamed: 26']

lgg = fix_df(lgg, lgg_col_names)

lgg_rename_dict = {'Unnamed: 1': 'Country',
                   'Unnamed: 2': 'Male to female births',
                   'Gross enrolment ratio': 'Gender enrolment ratio pre-primary',
                   'Unnamed: 6': 'Gender enrolment ratio primary',
                   'Unnamed: 8': 'Gender enrolment ratio secondary',
                   'Unnamed: 10': 'Youth unemployment rate gender ratio',
                   'Unnamed: 12': 'At least some secondary education gender ratio',
                   'Unnamed: 14': 'Total unemployment rate gender ratio',
                   'Unnamed: 16': 'Share of female employment in nonagriculture',
                   'Unnamed: 18': 'Share of seats held by women in parliament',
                   'Unnamed: 20': 'Share of seats held by women in local government',
                   'Unnamed: 22': 'Share of hour women spent on unpaid domestic chores and care work',
                   'Unnamed: 24': 'Time spent on unpaid domestic chores and care work gender ratio',
                   'Unnamed: 26': 'Old-age pension recipients gender ratio'}

lgg = lgg.rename(columns=lgg_rename_dict)

# %%
lgg
# Out:
#                                                Country  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                              Country
# 3                                                  NaN
# 4                          Very high human development
# ..                                                 ...
# 222                     Small island developing states
# 223                                                NaN
# 224  Organisation for Economic Co-operation and Dev...
# 225                                                NaN
# 226                                              World
#
#        Male to female births Gender enrolment ratio pre-primary  \
# 0         Sex ratio at birth             (female to male ratio)
# 1                        NaN                                NaN
# 2    (male to female births)                        Pre-primary
# 3                  2015–2020                          2014–2019
# 4                        NaN                                NaN
# ..                       ...                                ...
# 222                  1.05663                                 ..
# 223                      NaN                                NaN
# 224                  1.05232                            0.99892
# 225                      NaN                                NaN
# 226                   1.0688                           0.978824
#
#     Gender enrolment ratio primary Gender enrolment ratio secondary  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                          Primary                        Secondary
# 3                        2014–2019                        2014–2019
# 4                              NaN                              NaN
# ..                             ...                              ...
# 222                       0.949199                         0.996369
# 223                            NaN                              NaN
# 224                       0.995047                          1.00193
# 225                            NaN                              NaN
# 226                        1.00533                         0.995708
#
#     Youth unemployment rate gender ratio  \
# 0                Youth unemployment rate
# 1                                    NaN
# 2                 (female to male ratio)
# 3                                   2019
# 4                                    NaN
# ..                                   ...
# 222                               1.5619
# 223                                  NaN
# 224                              1.02855
# 225                                  NaN
# 226                              1.15442
#
#         At least some secondary education gender ratio  \
# 0    Population with at least some secondary education
# 1                                                  NaN
# 2                               (female to male ratio)
# 3                                            2015–2019
# 4                                                  NaN
# ..                                                 ...
# 222                                            0.94215
# 223                                                NaN
# 224                                           0.965681
# 225                                                NaN
# 226                                           0.893348
#
#     Total unemployment rate gender ratio  \
# 0                Total unemployment rate
# 1                                    NaN
# 2                 (female to male ratio)
# 3                                   2019
# 4                                    NaN
# ..                                   ...
# 222                              1.47375
# 223                                  NaN
# 224                              1.12482
# 225                                  NaN
# 226                               1.1813
#
#        Share of female employment in nonagriculture  \
# 0    Share of employment in nonagriculture, female
# 1                                               NaN
# 2         (% of total employment in nonagriculture)
# 3                                              2019
# 4                                               NaN
# ..                                              ...
# 222                                         43.7605
# 223                                             NaN
# 224                                         44.9911
# 225                                             NaN
# 226                                         39.4051
#
#     Share of seats held by women in parliament  \
# 0                 Share of seats held by women
# 1                                In parliament
# 2                                          (%)
# 3                                         2019
# 4                                          NaN
# ..                                         ...
# 222                                    25.0699
# 223                                        NaN
# 224                                    30.8327
# 225                                        NaN
# 226                                    24.6395
#
#     Share of seats held by women in local government  \
# 0                                                NaN
# 1                                In local government
# 2                                                NaN
# 3                                          2017–2019
# 4                                                NaN
# ..                                               ...
# 222                                                —
# 223                                              NaN
# 224                                                —
# 225                                              NaN
# 226                                                —
#
#     Share of hour women spent on unpaid domestic chores and care work  \
# 0    Time spent on unpaid domestic chores and care ...
# 1                              Women ages 15 and older
# 2                                   (% of 24-hour day)
# 3                                            2008–2018
# 4                                                  NaN
# ..                                                 ...
# 222                                                  —
# 223                                                NaN
# 224                                                  —
# 225                                                NaN
# 226                                                  —
#
#     Time spent on unpaid domestic chores and care work gender ratio  \
# 0                                                  NaN
# 1                                                  NaN
# 2                               (female to male ratio)
# 3                                            2008–2018
# 4                                                  NaN
# ..                                                 ...
# 222                                                  —
# 223                                                NaN
# 224                                                  —
# 225                                                NaN
# 226                                                  —
#
#     Old-age pension recipients gender ratio
# 0                Old-age pension recipients
# 1                                       NaN
# 2                    (female to male ratio)
# 3                                 2014–2019
# 4                                       NaN
# ..                                      ...
# 222                                      ..
# 223                                     NaN
# 224                                0.911424
# 225                                     NaN
# 226                                      ..
#
# [227 rows x 14 columns]

# %%
# Dashboard 3. Women's empowerment
we = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Dashboard 3', 9, 32)

we_col_names = ['Unnamed: 1', 'Women married by age 18', 'Share of graduates in science,\ntechnology,\nengineering\nand\nmathematics programmes at tertiary level, female',
                'Share of graduates from science,\ntechnology,\nengineering\nand\nmathematics programmes in tertiary education who are female',
                'Female share of employment in senior and middle management',
                'Women with account at financial institution or with mobile money-service provider',
                'Mandatory paid maternity leave', 'Intimate partner', 'Nonintimate partner']

we = fix_df(we, we_col_names)

# %%
we_rename_dict = {'Unnamed: 1': 'Country',
                  'Women married by age 18': 'Share of women married by age 18',
                  'Share of graduates in science,\ntechnology,\nengineering\nand\nmathematics programmes at tertiary level, female': 'Share of female in STEM tertiary education programs',
                  'Share of graduates from science,\ntechnology,\nengineering\nand\nmathematics programmes in tertiary education who are female': 'Share of female STEM tertiary education graduates',
                  'Mandatory paid maternity leave': 'Days of mandatory paid maternity leave',
                  'Intimate partner': 'Share of violence against women ever experienced by intimate partner',
                  'Nonintimate partner': 'Share of violence against women ever experienced by nonintimate partner'}
            
we = we.rename(columns=we_rename_dict)

# %%
we
# Out:
#                                                Country  \
# 0                                              Country
# 1                                                  NaN
# 2                          Very high human development
# 3                                               Norway
# 4                                              Ireland
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# 224                                              World
#
#                       Share of women married by age 18  \
# 0    (% of women ages 20–24 who are married or in u...
# 1                                            2005–2019
# 2                                                  NaN
# 3                                                   ..
# 4                                                   ..
# ..                                                 ...
# 220                                            23.9381
# 221                                                NaN
# 222                                                 ..
# 223                                                NaN
# 224                                                 ..
#
#     Share of female in STEM tertiary education programs  \
# 0                                                  (%)
# 1                                            2009–2019
# 2                                                  NaN
# 3                                              10.8837
# 4                                              14.1037
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                            12.9292
# 223                                                NaN
# 224                                                 ..
#
#     Share of female STEM tertiary education graduates  \
# 0                                                 (%)
# 1                                           2009–2019
# 2                                                 NaN
# 3                                             28.4643
# 4                                             29.0019
# ..                                                ...
# 220                                                ..
# 221                                               NaN
# 222                                           32.5817
# 223                                               NaN
# 224                                                ..
#
#     Female share of employment in senior and middle management  \
# 0                                                  (%)
# 1                                            2009–2019
# 2                                                  NaN
# 3                                                32.75
# 4                                                31.26
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                            36.7172
# 223                                                NaN
# 224                                                 ..
#
#     Women with account at financial institution or with mobile money-service provider  \
# 0           (% of female population ages 15 and older)
# 1                                                 2017
# 2                                                  NaN
# 3                                                  100
# 4                                               95.307
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                            84.5985
# 223                                                NaN
# 224                                            64.4552
#
#     Days of mandatory paid maternity leave  \
# 0                                   (days)
# 1                                     2019
# 2                                      NaN
# 3                                       ..
# 4                                      182
# ..                                     ...
# 220                                82.3448
# 221                                    NaN
# 222                                122.194
# 223                                    NaN
# 224                                110.034
#
#     Share of violence against women ever experienced by intimate partner  \
# 0           (% of female population ages 15 and older)
# 1                                            2005–2019
# 2                                                  NaN
# 3                                                   27
# 4                                                   15
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                                 ..
# 223                                                NaN
# 224                                                 ..
#
#     Share of violence against women ever experienced by nonintimate partner
# 0                                                  NaN
# 1                                            2005–2019
# 2                                                  NaN
# 3                                                   ..
# 4                                                    5
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                                 ..
# 223                                                NaN
# 224                                                 ..
#
# [225 rows x 9 columns]

# %%
# Dashboard 5. Socioeconomic sustainability
ses = read_human_dev_report('Human Development Reports/2020_statistical_annex_all.xlsx', 'Dashboard 5', 9, 52)

ses_col_names = ['Unnamed: 1', 'Skilled labour force', 'Ratio of education and health expenditure to military expenditure']

ses = fix_df(ses, ses_col_names)

# %%
ses_rename_dict = {'Unnamed: 1': 'Country',
                   'Skilled labour force': 'Share of skilled labour force'}

ses = ses.rename(columns=ses_rename_dict)

# %%
ses
# Out:
#                                                Country  \
# 0                                              Country
# 1                                                  NaN
# 2                          Very high human development
# 3                                               Norway
# 4                                              Ireland
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# 224                                              World
#
#     Share of skilled labour force  \
# 0             (% of labour force)
# 1                       2010–2019
# 2                             NaN
# 3                         84.2811
# 4                          85.047
# ..                            ...
# 220                       46.4152
# 221                           NaN
# 222                       81.4971
# 223                           NaN
# 224                       47.2803
#
#     Ratio of education and health expenditure to military expenditure
# 0                                                  NaN
# 1                                            2010–2017
# 2                                                  NaN
# 3                                              11.4477
# 4                                              33.4942
# ..                                                 ...
# 220                                                 ..
# 221                                                NaN
# 222                                            7.81891
# 223                                                NaN
# 224                                            6.66717
#
# [225 rows x 3 columns]

# %%
# All the dfs we created
all_dfs = [hdi, gdi, ea, hcm, qhd, lgg, we, ses]

# %%
hdr_df = reduce(lambda left, right: pd.merge(left, right, on='Country', how='outer'), all_dfs).reset_index()

# %%
row_to_remove = ['Country', 'Regions', 'Human development groups', 'VERY HIGH HUMAN DEVELOPMENT',
                 'HIGH HUMAN DEVELOPMENT', 'MEDIUM HUMAN DEVELOPMENT', 'LOW HUMAN DEVELOPMENT',
                 'OTHER COUNTRIES OR TERRITORIES']

# %%
hdr_df = hdr_df[~hdr_df['Country'].isin(row_to_remove)]

# %%
hdr_df = hdr_df[~hdr_df['Country'].isnull()]

# %%
hdr_df = pd.merge(hdr_df, gii, on='Country', how='left')

# %%
hdr_new = hdr_df.iloc[0:195]

# %%
# clean up country names to match Read Country Code file
to_replace_ = ['Palestine, State of', 'Hong Kong, China (SAR)', 'Russian Federation', 
               'Korea (Republic of)', 'Iran (Islamic Republic of)']
replace_with_ = ['Palestine', 'Hong Kong', 'Russia', 
                 'South Korea', 'Iran']

def fix_country_names(df, col_name):
    df[col_name] = df[col_name].replace(to_replace_, replace_with_)
    df[col_name] = df[col_name].replace('[\(].*[\)]', '', regex=True)
    
    return df

# %%
# copy human development report from countries to countries with cities and the UK
def update_country_cities(df, df_new_col, df_UK_col):
    df.loc['Canada, Ontario', df_new_col] = df.loc['Canada', df_new_col]
    df.loc['Canada, Quebec', df_new_col] = df.loc['Canada', df_new_col]
    df.loc['Russia, Moscow', df_new_col] = df.loc['Russia', df_new_col]
    df.loc['United Arab Emirates, Abu Dhabi', df_new_col] = df.loc['United Arab Emirates', df_new_col]
    df.loc['United Arab Emirates, Dubai', df_new_col] = df.loc['United Arab Emirates', df_new_col]
    df.loc['England', df_new_col] = df_UK_col
    df.loc['Northern Ireland', df_new_col] = df_UK_col

    return df

# %%
# obtain columns and values for cities and UK

hdr_new_col = list(hdr_new.columns.values[2:])
hdr_new_UK_col = hdr_new.set_index('Country').loc['United Kingdom']

# merge columns from Read Country Code
hdr_new_1 = fix_country_names(hdr_new, 'Country')#.set_index('Country')
hdr_new_1 = country_ids.merge(hdr_new_1, how='left', on='Country')#.set_index('Country')
hdr_new_1 = hdr_new_1.set_index('Country')

# populate countries with cities and UK
hdr_new_2 = update_country_cities(hdr_new_1, hdr_new_col, hdr_new_UK_col)#.reset_index()
# Out:
# <ipython-input-38-c9309a2bc7ef>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name] = df[col_name].replace(to_replace_, replace_with_)
# <ipython-input-38-c9309a2bc7ef>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name] = df[col_name].replace('[\(].*[\)]', '', regex=True)

# %%
hdr_new_2 = hdr_new_2.replace('..', np.nan)

# %%
hdr_new_2 = hdr_new_2.reset_index().drop(columns='Unnamed: 0')

# %%
hdr_new_2
# Out:
#                             Country  country_ID grade_4 grade_8      index  \
# 0                           Albania           8     yes      no  9680903.0
# 1                           Armenia          51     yes      no  9680915.0
# 2                         Australia          36     yes     yes  9680841.0
# 3                           Austria          40     yes      no  9680851.0
# 4                        Azerbaijan          31     yes      no  9680922.0
# ..                              ...         ...     ...     ...        ...
# 64                           Turkey         792     yes     yes  9680887.0
# 65             United Arab Emirates         784     yes     yes  9680864.0
# 66  United Arab Emirates, Abu Dhabi        7842     yes     yes        NaN
# 67      United Arab Emirates, Dubai        7841     yes     yes        NaN
# 68                    United States         840     yes     yes  9680850.0
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 0                           0.795                     78.57
# 1                           0.776                     75.09
# 2                           0.944                     83.44
# 3                           0.922                     81.54
# 4                           0.756                     73.01
# ..                            ...                       ...
# 64                          0.820                     77.69
# 65                          0.890                     77.97
# 66                          0.890                     77.97
# 67                          0.890                     77.97
# 68                          0.926                     78.86
#
#     Expected years of schooling  Mean years of schooling  \
# 0                     14.695620                10.145730
# 1                     13.068610                11.301740
# 2                     21.954330                12.724691
# 3                     16.092070                12.546144
# 4                     12.893640                10.575430
# ..                          ...                      ...
# 64                    16.602666                 8.106820
# 65                    14.344100                12.111220
# 66                    14.344100                12.111220
# 67                    14.344100                12.111220
# 68                    16.310390                13.413440
#
#     Gross national income (GNI) per capita  ...  \
# 0                              13998.29989  ...
# 1                              13894.01302  ...
# 2                              48084.84207  ...
# 3                              56196.89869  ...
# 4                              13783.67995  ...
# ..                                     ...  ...
# 64                             27700.89481  ...
# 65                             67462.09530  ...
# 66                             67462.09530  ...
# 67                             67462.09530  ...
# 68                             63825.65748  ...
#
#     Ratio of education and health expenditure to military expenditure  \
# 0                                                 NaN
# 1                                            3.403877
# 2                                            6.912926
# 3                                           21.732280
# 4                                            2.371953
# ..                                                ...
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                           6.174673
#
#     Gender Inequality Index  GII Rank  Maternal mortality ratio  \
# 0                     0.181      42.0                      15.0
# 1                     0.245      54.0                      26.0
# 2                     0.097      25.0                       6.0
# 3                     0.069      14.0                       5.0
# 4                     0.323      73.0                      26.0
# ..                      ...       ...                       ...
# 64                    0.306      68.0                      17.0
# 65                    0.079      18.0                       3.0
# 66                    0.079      18.0                       3.0
# 67                    0.079      18.0                       3.0
# 68                    0.204      46.0                      19.0
#
#     Adolescent birth rate  Share of seats in parliament held by women  \
# 0                  19.642                                   29.508197
# 1                  21.490                                   23.484848
# 2                  11.715                                   36.563877
# 3                   7.340                                   38.524590
# 4                  55.838                                   16.806723
# ..                    ...                                         ...
# 64                 26.559                                   17.449664
# 65                  6.546                                   50.000000
# 66                  6.546                                   50.000000
# 67                  6.546                                   50.000000
# 68                 19.860                                   23.728814
#
#     Share at least some secondary education Female  \
# 0                                        93.699746
# 1                                        97.268054
# 2                                        91.025070
# 3                                       100.000000
# 4                                        93.901900
# ..                                             ...
# 64                                       50.159190
# 65                                       76.022570
# 66                                       76.022570
# 67                                       76.022570
# 68                                       96.075970
#
#     Share at least some secondary education Male  \
# 0                                      92.497154
# 1                                      97.151720
# 2                                      90.944520
# 3                                      99.787054
# 4                                      97.500760
# ..                                           ...
# 64                                     72.237686
# 65                                     81.028510
# 66                                     81.028510
# 67                                     81.028510
# 68                                     95.979220
#
#     Labour force participation rate Female  \
# 0                                   46.712
# 1                                   47.074
# 2                                   60.300
# 3                                   55.059
# 4                                   63.411
# ..                                     ...
# 64                                  34.013
# 65                                  52.391
# 66                                  52.391
# 67                                  52.391
# 68                                  56.126
#
#     Labour force participation rate Male
# 0                                 64.568
# 1                                 65.887
# 2                                 70.855
# 3                                 66.573
# 4                                 69.737
# ..                                   ...
# 64                                72.586
# 65                                93.389
# 66                                93.389
# 67                                93.389
# 68                                68.186
#
# [69 rows x 84 columns]

# %%
hdr_df.to_csv('hdr_df_new.csv', index=False)
